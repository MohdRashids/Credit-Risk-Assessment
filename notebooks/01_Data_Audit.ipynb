# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/raw/german_credit_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose  Risk
# 0           1169         6             radio/TV  good
# 1           5951        48             radio/TV   bad
# 2           2096        12            education  good
# 3           7882        42  furniture/equipment  good
# 4           4870        24                  car   bad

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Sex               1000 non-null   str
#  3   Job               1000 non-null   int64
#  4   Housing           1000 non-null   str
#  5   Saving accounts   817 non-null    str
#  6   Checking account  606 non-null    str
#  7   Credit amount     1000 non-null   int64
#  8   Duration          1000 non-null   int64
#  9   Purpose           1000 non-null   str
#  10  Risk              1000 non-null   str
# dtypes: int64(5), str(6)
# memory usage: 115.1 KB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Sex               1000 non-null   str
#  3   Job               1000 non-null   int64
#  4   Housing           1000 non-null   str
#  5   Saving accounts   817 non-null    str
#  6   Checking account  606 non-null    str
#  7   Credit amount     1000 non-null   int64
#  8   Duration          1000 non-null   int64
#  9   Purpose           1000 non-null   str
#  10  Risk              1000 non-null   str
# dtypes: int64(5), str(6)
# memory usage: 115.1 KB

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64

# %% [markdown]
# The dataset contains 1000 loan applications and 11 variables.
#
# The target variable is **Risk**, which classifies applicants into **good** and **bad** credit risk.
#
# The dataset contains both numerical and categorical variables, making it suitable for descriptive statistics, probability analysis, hypothesis testing, and predictive modeling.

# %%
df.describe()
# Out:
#         Unnamed: 0          Age          Job  Credit amount     Duration
# count  1000.000000  1000.000000  1000.000000    1000.000000  1000.000000
# mean    499.500000    35.546000     1.904000    3271.258000    20.903000
# std     288.819436    11.375469     0.653614    2822.736876    12.058814
# min       0.000000    19.000000     0.000000     250.000000     4.000000
# 25%     249.750000    27.000000     2.000000    1365.500000    12.000000
# 50%     499.500000    33.000000     2.000000    2319.500000    18.000000
# 75%     749.250000    42.000000     2.000000    3972.250000    24.000000
# max     999.000000    75.000000     3.000000   18424.000000    72.000000

# %%
df.describe(include="object")
# Out:
# C:\Users\khanr\AppData\Local\Temp\ipykernel_9904\702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#          Sex Housing Saving accounts Checking account Purpose  Risk
# count   1000    1000             817              606    1000  1000
# unique     2       3               4                3       8     2
# top     male     own          little           little     car  good
# freq     690     713             603              274     337   700

# %%
df["Risk"].value_counts()
# Out:
# Risk
# good    700
# bad     300
# Name: count, dtype: int64

# %%
df["Risk"].value_counts(normalize=True)*100
# Out:
# Risk
# good    70.0
# bad     30.0
# Name: proportion, dtype: float64

# %%
df.nunique()
# Out:
# Unnamed: 0          1000
# Age                   53
# Sex                    2
# Job                    4
# Housing                3
# Saving accounts        4
# Checking account       3
# Credit amount        921
# Duration              33
# Purpose                8
# Risk                   2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# Age                 int64
# Sex                   str
# Job                 int64
# Housing               str
# Saving accounts       str
# Checking account      str
# Credit amount       int64
# Duration            int64
# Purpose               str
# Risk                  str
# dtype: object

# %%
df.memory_usage(deep=True)
# Out:
# Index                 132
# Unnamed: 0           8000
# Age                  8000
# Sex                 12620
# Job                  8000
# Housing             11287
# Saving accounts     13389
# Checking account    12173
# Credit amount        8000
# Duration             8000
# Purpose             16559
# Risk                11700
# dtype: int64
